# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/depression-audio-dataset/corr-freq.csv
# /kaggle/input/depression-audio-dataset/participant-info.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/test_split_temp-35.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/test_split_Depression_AVEC2017.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/dev_split_temp-10.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/train_split_temp-35.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/dev_split_Depression_AVEC2017.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/train_split_temp-10.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/test_split_temp-10.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/dev_split_big.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/full_test_split.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/train_split_big.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/train_split_Depression_AVEC2017.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/dev_split_temp-35.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/full_test_split_big.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/437/437_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/437/437_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/479/479_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/479/479_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/313/313_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/313/313_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/466/466_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/466/466_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/480/480_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/480/480_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/395/395_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/395/395_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/429/429_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/429/429_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/485/485_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/485/485_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/463/463_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/463/463_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/330/330_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/330/330_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/363/363_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/363/363_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/419/419_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/419/419_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/406/406_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/406/406_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/309/309_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/309/309_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/462/462_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/462/462_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/336/336_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/336/336_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/303/303_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/303/303_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/447/447_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/447/447_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/484/484_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/484/484_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/403/403_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/403/403_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/446/446_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/446/446_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/311/311_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/311/311_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/491/491_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/491/491_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/449/449_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/449/449_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/352/352_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/352/352_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/476/476_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/476/476_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/372/372_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/372/372_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/408/408_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/408/408_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/367/367_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/367/367_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/318/318_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/318/318_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/355/355_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/355/355_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/465/465_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/465/465_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/405/405_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/405/405_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/435/435_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/435/435_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/459/459_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/459/459_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/359/359_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/359/359_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/478/478_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/478/478_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/369/369_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/369/369_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/443/443_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/443/443_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/379/379_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/379/379_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/415/415_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/415/415_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/444/444_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/444/444_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/392/392_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/392/392_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/304/304_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/304/304_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/458/458_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/458/458_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/339/339_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/339/339_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/346/346_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/346/346_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/416/416_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/416/416_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/453/453_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/453/453_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/343/343_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/343/343_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/331/331_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/331/331_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/324/324_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/324/324_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/490/490_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/490/490_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/338/338_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/338/338_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/351/351_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/351/351_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/350/350_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/350/350_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/404/404_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/404/404_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/329/329_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/329/329_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/434/434_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/434/434_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/399/399_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/399/399_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/325/325_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/325/325_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/375/375_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/375/375_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/302/302_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/302/302_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/474/474_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/474/474_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/327/327_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/327/327_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/393/393_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/393/393_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/442/442_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/442/442_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/417/417_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/417/417_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/320/320_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/320/320_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/306/306_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/306/306_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/452/452_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/452/452_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/481/481_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/481/481_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/344/344_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/344/344_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/412/412_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/412/412_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/312/312_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/312/312_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/430/430_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/430/430_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/483/483_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/483/483_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/308/308_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/308/308_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/410/410_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/410/410_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/432/432_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/432/432_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/348/348_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/348/348_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/378/378_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/378/378_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/333/333_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/333/333_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/341/341_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/341/341_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/433/433_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/433/433_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/441/441_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/441/441_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/448/448_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/448/448_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/425/425_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/425/425_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/364/364_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/364/364_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/347/347_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/347/347_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/305/305_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/305/305_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/337/337_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/337/337_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/360/360_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/360/360_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/316/316_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/316/316_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/473/473_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/473/473_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/477/477_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/477/477_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/445/445_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/445/445_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/391/391_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/391/391_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/362/362_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/362/362_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/411/411_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/411/411_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/361/361_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/361/361_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/328/328_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/328/328_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/307/307_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/307/307_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/354/354_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/354/354_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/353/353_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/353/353_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/389/389_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/389/389_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/439/439_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/439/439_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/418/418_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/418/418_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/335/335_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/335/335_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/470/470_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/470/470_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/451/451_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/451/451_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/345/345_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/345/345_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/468/468_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/468/468_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/436/436_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/436/436_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/371/371_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/371/371_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/356/356_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/356/356_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/455/455_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/455/455_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/314/314_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/314/314_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/467/467_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/467/467_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/450/450_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/450/450_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/349/349_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/349/349_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/385/385_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/385/385_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/377/377_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/377/377_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/424/424_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/424/424_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/390/390_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/390/390_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/397/397_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/397/397_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/487/487_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/487/487_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/381/381_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/381/381_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/376/376_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/376/376_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/382/382_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/382/382_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/428/428_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/428/428_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/370/370_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/370/370_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/426/426_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/426/426_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/366/366_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/366/366_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/383/383_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/383/383_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/421/421_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/421/421_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/423/423_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/423/423_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/387/387_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/387/387_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/401/401_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/401/401_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/374/374_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/374/374_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/340/340_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/340/340_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/482/482_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/482/482_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/300/300_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/300/300_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/489/489_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/489/489_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/472/472_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/472/472_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/438/438_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/438/438_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/414/414_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/414/414_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/386/386_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/386/386_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/464/464_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/464/464_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/400/400_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/400/400_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/310/310_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/310/310_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/358/358_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/358/358_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/457/457_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/457/457_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/454/454_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/454/454_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/373/373_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/373/373_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/322/322_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/322/322_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/456/456_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/456/456_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/422/422_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/422/422_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/431/431_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/431/431_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/409/409_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/409/409_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/365/365_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/365/365_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/413/413_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/413/413_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/407/407_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/407/407_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/317/317_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/317/317_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/380/380_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/380/380_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/321/321_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/321/321_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/461/461_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/461/461_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/402/402_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/402/402_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/384/384_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/384/384_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/396/396_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/396/396_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/420/420_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/420/420_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/469/469_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/469/469_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/486/486_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/486/486_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/427/427_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/427/427_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/332/332_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/332/332_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/440/440_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/440/440_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/368/368_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/368/368_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/492/492_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/492/492_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/388/388_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/388/388_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/475/475_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/475/475_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/334/334_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/334/334_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/315/315_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/315/315_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/301/301_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/301/301_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/471/471_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/471/471_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/488/488_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/488/488_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/323/323_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/323/323_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/326/326_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/326/326_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/357/357_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/357/357_AUDIO.wav
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/319/319_TRANSCRIPT.csv
# /kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/319/319_AUDIO.wav

# %%
# !pip install ipython-autotime
# !pip install opensmile
# %load_ext autotime
# %matplotlib inline
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.10/site-packages (from ipython-autotime) (8.20.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (5.9.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-autotime) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->ipython-autotime) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->ipython-autotime) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython->ipython-autotime) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython->ipython-autotime) (1.16.0)
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.3.2
# Collecting opensmile
#   Downloading opensmile-2.5.0-py3-none-manylinux_2_17_x86_64.whl.metadata (15 kB)
# Collecting audobject>=0.6.1 (from opensmile)
#   Downloading audobject-0.7.11-py3-none-any.whl.metadata (2.6 kB)
# Collecting audinterface>=0.7.0 (from opensmile)
#   Downloading audinterface-1.2.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting audeer>=1.18.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audeer-2.2.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting audformat<2.0.0,>=1.0.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audformat-1.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting audiofile>=1.3.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audiofile-1.5.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting audmath>=1.4.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audmath-1.4.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting audresample<2.0.0,>=1.1.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audresample-1.3.3-py3-none-manylinux_2_17_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from audobject>=0.6.1->opensmile) (6.11.0)
# Collecting oyaml (from audobject>=0.6.1->opensmile)
#   Downloading oyaml-1.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from audobject>=0.6.1->opensmile) (21.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from audeer>=1.18.0->audinterface>=0.7.0->opensmile) (4.66.4)
# Collecting iso-639 (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.4/167.4 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iso3166 (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso3166-2.1.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.2.2)
# Requirement already satisfied: pyarrow>=10.0.1 in /opt/conda/lib/python3.10/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (16.1.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /opt/conda/lib/python3.10/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (6.0.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.26.4)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (0.12.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (3.17.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->audobject>=0.6.1->opensmile) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2023.4)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (1.16.0)
# Downloading opensmile-2.5.0-py3-none-manylinux_2_17_x86_64.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.2/996.2 kB 33.1 MB/s eta 0:00:00
# Downloading audinterface-1.2.2-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 3.6 MB/s eta 0:00:00
# Downloading audobject-0.7.11-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.5 MB/s eta 0:00:00
# Downloading audeer-2.2.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 1.8 MB/s eta 0:00:00
# Downloading audformat-1.3.0-py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.3/151.3 kB 8.4 MB/s eta 0:00:00
# Downloading audiofile-1.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.8 MB/s eta 0:00:00
# Downloading audmath-1.4.1-py3-none-any.whl (23 kB)
# Downloading audresample-1.3.3-py3-none-manylinux_2_17_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.4/138.4 kB 8.4 MB/s eta 0:00:00
# Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: iso-639
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=168840 sha256=27b02b6ab7b957bff2cc200b7cbe845f05a266393ba4ddfee6a7d26a906eb091
#   Stored in directory: /root/.cache/pip/wheels/d8/78/cc/5478ca3b1c3f602eae6f8cdbd78f909c0a0bfa0bbcb5c7771f
# Successfully built iso-639
# Installing collected packages: iso-639, oyaml, iso3166, audresample, audmath, audeer, audobject, audiofile, audformat, audinterface, opensmile
# Successfully installed audeer-2.2.0 audformat-1.3.0 audinterface-1.2.2 audiofile-1.5.0 audmath-1.4.1 audobject-0.7.11 audresample-1.3.3 iso-639-0.4.5 iso3166-2.1.1 opensmile-2.5.0 oyaml-1.0
# time: 2.35 ms (started: 2024-08-06 11:53:40 +00:00)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import opensmile
import os
import gc
import tempfile
import soundfile as sf
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.preprocessing import MinMaxScaler
from scipy.io import wavfile
# Out:
# time: 2.47 s (started: 2024-08-06 11:53:40 +00:00)

# %%
BASE_DIR = "/kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle"
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# Load main CSV file with participant information
participant_info = pd.read_csv("/kaggle/input/depression-audio-dataset/participant-info.csv")
participant_info_fig = pd.read_csv("/kaggle/input/depression-audio-dataset/corr-freq.csv")

# Display correlation matrix
correlation_matrix = participant_info_fig.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Participant Information")
plt.show()

# Map gender from 0, 1 to 'Male', 'Female' if necessary
if participant_info['Gender'].dtype == np.int64:
    participant_info['Gender'] = participant_info['Gender'].map({0: 'Male', 1: 'Female'})

# Create the gender distribution plot
plt.figure(figsize=(10, 6))
sns.countplot(data=participant_info, x='PHQ8_Binary', hue='Gender', palette=['#1f77b4', '#ff7f0e'])
plt.title("Gender Distribution of Depressed and Non-Depressed Individuals", fontsize=14)
plt.xlabel("Not depressed (0) / Depressed (1)", fontsize=12)
plt.ylabel("Count", fontsize=12)
for i in plt.gca().containers:
    plt.gca().bar_label(i, label_type='edge')
plt.legend(title="Gender", loc='upper right')
plt.tight_layout()
plt.show()

# Calculate and display percentages
gender_depression = participant_info.groupby(['Gender', 'PHQ8_Binary']).size().unstack()
for gender in gender_depression.index:
    total = gender_depression.loc[gender].sum()
    depressed = gender_depression.loc[gender, 1]
    percentage = (depressed / total) * 100
    print(f"Percentage of depressed {gender}s: {percentage:.1f}%")
# Out:
# Percentage of depressed Females: 24.5%
# Percentage of depressed Males: 35.6%
# time: 1.49 s (started: 2024-08-06 11:53:42 +00:00)

# %%
def get_participant_paths(participant_id):
    folder = f'{BASE_DIR}/{participant_id}/'
    return f'{folder}{participant_id}_AUDIO.wav', f'{folder}{participant_id}_TRANSCRIPT.csv'

def load_data(participant_id):
    audio_file, transcript_file = get_participant_paths(participant_id)
    y, sr = librosa.load(audio_file)
    transcript = pd.read_csv(transcript_file, sep='\t', header=None,
                             names=['start_time', 'stop_time', 'speaker', 'value'])
    if transcript.iloc[0]['start_time'] == 'start_time':
        transcript = transcript.iloc[1:]
    transcript['start_time'] = transcript['start_time'].astype(float)
    transcript['stop_time'] = transcript['stop_time'].astype(float)
    return y, sr, transcript

def segment_audio(y, sr, transcript):
    participant_segments = transcript[transcript['speaker'] != 'Ellie'].dropna(subset=['start_time', 'stop_time'])
    return np.concatenate([
        y[int(segment['start_time'] * sr):int(segment['stop_time'] * sr)]
        for _, segment in participant_segments.iterrows()
    ])

def extract_opensmile_features(audio, sr):
    smile = opensmile.Smile(
        feature_set=opensmile.FeatureSet.eGeMAPSv02,
        feature_level=opensmile.FeatureLevel.Functionals,
    )
    
    with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as temp_audio:
        sf.write(temp_audio.name, audio, sr)
        features = smile.process_file(temp_audio.name)
    
    os.unlink(temp_audio.name)
    
    opensmile_features = features.values.flatten()
    
    return opensmile_features, features.columns.tolist()

def process_participant(participant_id):
    y, sr, transcript = load_data(participant_id)
    segmented_audio = segment_audio(y, sr, transcript)
    features, feature_names = extract_opensmile_features(segmented_audio, sr)
    del y, transcript, segmented_audio
    gc.collect()
    return features, feature_names

def augment_audio(audio, sr):
    choice = np.random.choice(['time_stretch', 'pitch_shift'])
    if choice == 'time_stretch':
        rate = np.random.uniform(0.8, 1.2)
        return librosa.effects.time_stretch(audio, rate=rate)
    else:  # pitch_shift
        n_steps = np.random.uniform(-2, 2)
        return librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

def feature_generator(data_file, augment=False):
    data = pd.read_csv(data_file)
    depression_column = 'PHQ8_Binary' if 'PHQ8_Binary' in data.columns else 'PHQ_Binary'
    for _, row in data.iterrows():
        participant_id = int(row['Participant_ID'])
        print(f"Processing participant_id: {participant_id}")
        y, sr, transcript = load_data(participant_id)
        segmented_audio = segment_audio(y, sr, transcript)
        features, feature_names = extract_opensmile_features(segmented_audio, sr)
        yield features, row[depression_column], feature_names
        
        if augment and row[depression_column] == 1:
            augmented_audio = augment_audio(segmented_audio, sr)
            augmented_features, _ = extract_opensmile_features(augmented_audio, sr)
            yield augmented_features, 1, feature_names
        
        del y, transcript, segmented_audio
        gc.collect()

def process_dataset(data_file, augment=False):
    X = []
    y_binary = []
    feature_names = None
    for features, label_binary, names in feature_generator(data_file, augment):
        X.append(features)
        y_binary.append(label_binary)
        if feature_names is None:
            feature_names = names
        gc.collect()
    return np.array(X), np.array(y_binary), feature_names
# Out:
# time: 7.03 ms (started: 2024-08-06 14:48:54 +00:00)

# %%
print("Processing test data...")
X_test, y_test, _ = process_dataset('/kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/full_test_split.csv', augment=True)
print("Test data processed.")

# Process datasets
print("Processing train data...")
X_train, y_train, feature_names = process_dataset('/kaggle/input/depression-audio-dataset/corr-freq.csv', augment=True)
print("Train data processed.")
# Out:
# Processing test data...
# Processing participant_id: 300
# Processing participant_id: 301
# Processing participant_id: 306
# Processing participant_id: 308
# Processing participant_id: 309
# Processing participant_id: 311
# Processing participant_id: 314
# Processing participant_id: 323
# Processing participant_id: 329
# Processing participant_id: 332
# Processing participant_id: 334
# Processing participant_id: 337
# Processing participant_id: 349
# Processing participant_id: 354
# Processing participant_id: 359
# Processing participant_id: 361
# Processing participant_id: 365
# Processing participant_id: 373
# Processing participant_id: 405
# Processing participant_id: 407
# Processing participant_id: 408
# Processing participant_id: 410
# Processing participant_id: 411
# Processing participant_id: 421
# Processing participant_id: 424
# Processing participant_id: 431
# Processing participant_id: 432
# Processing participant_id: 435
# Processing participant_id: 438
# Processing participant_id: 442
# Processing participant_id: 450
# Processing participant_id: 452
# Processing participant_id: 453
# Processing participant_id: 461
# Processing participant_id: 462
# Processing participant_id: 465
# Processing participant_id: 466
# Processing participant_id: 467
# Processing participant_id: 469
# Processing participant_id: 470
# Processing participant_id: 480
# Processing participant_id: 481
# Test data processed.
# Processing train data...
# Processing participant_id: 303
# Processing participant_id: 304
# Processing participant_id: 305
# Processing participant_id: 310
# Processing participant_id: 312
# Processing participant_id: 313
# Processing participant_id: 315
# Processing participant_id: 316
# Processing participant_id: 317
# Processing participant_id: 318
# Processing participant_id: 319
# Processing participant_id: 320
# Processing participant_id: 321
# Processing participant_id: 322
# Processing participant_id: 324
# Processing participant_id: 325
# Processing participant_id: 326
# Processing participant_id: 327
# Processing participant_id: 328
# Processing participant_id: 330
# Processing participant_id: 333
# Processing participant_id: 336
# Processing participant_id: 338
# Processing participant_id: 339
# Processing participant_id: 340
# Processing participant_id: 341
# Processing participant_id: 343
# Processing participant_id: 344
# Processing participant_id: 345
# Processing participant_id: 347
# Processing participant_id: 348
# Processing participant_id: 350
# Processing participant_id: 351
# Processing participant_id: 352
# Processing participant_id: 353
# Processing participant_id: 355
# Processing participant_id: 356
# Processing participant_id: 357
# Processing participant_id: 358
# Processing participant_id: 360
# Processing participant_id: 362
# Processing participant_id: 363
# Processing participant_id: 364
# Processing participant_id: 366
# Processing participant_id: 368
# Processing participant_id: 369
# Processing participant_id: 370
# Processing participant_id: 371
# Processing participant_id: 372
# Processing participant_id: 374
# Processing participant_id: 375
# Processing participant_id: 376
# Processing participant_id: 379
# Processing participant_id: 380
# Processing participant_id: 383
# Processing participant_id: 385
# Processing participant_id: 386
# Processing participant_id: 391
# Processing participant_id: 392
# Processing participant_id: 393
# Processing participant_id: 397
# Processing participant_id: 400
# Processing participant_id: 401
# Processing participant_id: 402
# Processing participant_id: 409
# Processing participant_id: 412
# Processing participant_id: 414
# Processing participant_id: 415
# Processing participant_id: 416
# Processing participant_id: 419
# Processing participant_id: 423
# Processing participant_id: 425
# Processing participant_id: 426
# Processing participant_id: 427
# Processing participant_id: 428
# Processing participant_id: 429
# Processing participant_id: 430
# Processing participant_id: 433
# Processing participant_id: 434
# Processing participant_id: 437
# Processing participant_id: 441
# Processing participant_id: 443
# Processing participant_id: 444
# Processing participant_id: 445
# Processing participant_id: 446
# Processing participant_id: 447
# Processing participant_id: 448
# Processing participant_id: 449
# Processing participant_id: 454
# Processing participant_id: 455
# Processing participant_id: 456
# Processing participant_id: 457
# Processing participant_id: 459
# Processing participant_id: 463
# Processing participant_id: 464
# Processing participant_id: 468
# Processing participant_id: 471
# Processing participant_id: 473
# Processing participant_id: 474
# Processing participant_id: 475
# Processing participant_id: 478
# Processing participant_id: 479
# Processing participant_id: 485
# Processing participant_id: 486
# Processing participant_id: 487
# Processing participant_id: 488
# Processing participant_id: 491
# Processing participant_id: 302
# Processing participant_id: 307
# Processing participant_id: 331
# Processing participant_id: 335
# Processing participant_id: 346
# Processing participant_id: 367
# Processing participant_id: 377
# Processing participant_id: 381
# Processing participant_id: 382
# Processing participant_id: 388
# Processing participant_id: 389
# Processing participant_id: 390
# Processing participant_id: 395
# Processing participant_id: 403
# Processing participant_id: 404
# Processing participant_id: 406
# Processing participant_id: 413
# Processing participant_id: 417
# Processing participant_id: 418
# Processing participant_id: 420
# Processing participant_id: 422
# Processing participant_id: 436
# Processing participant_id: 439
# Processing participant_id: 440
# Processing participant_id: 451
# Processing participant_id: 458
# Processing participant_id: 472
# Processing participant_id: 476
# Processing participant_id: 477
# Processing participant_id: 482
# Processing participant_id: 483
# Processing participant_id: 484
# Processing participant_id: 489
# Processing participant_id: 490
# Processing participant_id: 492
# Train data processed.
# time: 1h 39min 22s (started: 2024-08-06 11:53:44 +00:00)

# %%
print(Counter(y_train))
print(Counter(y_test))
# Out:
# Counter({0.0: 100, 1.0: 84})
# Counter({0: 33, 1: 28})
# time: 1.15 ms (started: 2024-08-06 13:37:56 +00:00)

# %%
# Balance the training set
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)
# Out:
# time: 164 ms (started: 2024-08-06 13:38:04 +00:00)

# %%
print("Train set distribution after balancing:", Counter(y_train_balanced))
# Out:
# Train set distribution after balancing: Counter({0.0: 100, 1.0: 100})
# time: 1.03 ms (started: 2024-08-06 13:38:12 +00:00)

# %%
scaler = MinMaxScaler()
X_train_balanced_scaled = scaler.fit_transform(X_train_balanced)
X_test_scaled = scaler.transform(X_test)
# Out:
# time: 4.07 ms (started: 2024-08-06 17:36:16 +00:00)

# %%
# Base models with default parameters
decision_tree_default = DecisionTreeClassifier(random_state=42)
random_forest_default = RandomForestClassifier(random_state=42)
gradient_boosting_default = GradientBoostingClassifier(random_state=42)
knn_default = KNeighborsClassifier()

# Fit the base models
decision_tree_default.fit(X_train_balanced_scaled, y_train_balanced)
random_forest_default.fit(X_train_balanced_scaled, y_train_balanced)
gradient_boosting_default.fit(X_train_balanced_scaled, y_train_balanced)
knn_default.fit(X_train_balanced_scaled, y_train_balanced)

# Define the hard voting classifier
voting_clf_default = VotingClassifier(
    estimators=[
        ('decision_tree', decision_tree_default),
        ('random_forest', random_forest_default),
        ('gradient_boosting', gradient_boosting_default),
        ('knn', knn_default)
    ],
    voting='hard'
)

# Fit the Voting Classifier
voting_clf_default.fit(X_train_balanced_scaled, y_train_balanced)

# Predict and evaluate
y_pred_voting_default = voting_clf_default.predict(X_test_scaled)
accuracy_voting_default = accuracy_score(y_test, y_pred_voting_default)
precision_voting_default = precision_score(y_test, y_pred_voting_default)
recall_voting_default = recall_score(y_test, y_pred_voting_default)
f1_voting_default = f1_score(y_test, y_pred_voting_default)

print("Default Hard Voting Classifier Results:")
print(f"Accuracy: {accuracy_voting_default:.4f}")
print(f"Precision: {precision_voting_default:.4f}")
print(f"Recall: {recall_voting_default:.4f}")
print(f"F1 Score: {f1_voting_default:.4f}")
print(classification_report(y_test, y_pred_voting_default))

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title, fontsize=16, pad=20)
    plt.colorbar()
    tick_marks = np.arange(2)
    plt.xticks(tick_marks, ['0', '1'], fontsize=12)
    plt.yticks(tick_marks, ['0', '1'], fontsize=12)
    plt.ylabel('True label', fontsize=14)
    plt.xlabel('Predicted label', fontsize=14)
    
    # Add text annotations
    thresh = cm.max() / 2.
    for i in range(2):
        for j in range(2):
            plt.text(j, i, str(cm[i, j]),
                     ha="center", va="center",
                     color="white" if cm[i, j] > thresh else "black",
                     fontsize=14)
    
    # Adjust layout and save
    plt.tight_layout(pad=3.0)
    plt.savefig(f"{title.replace(' ', '_')}.png", bbox_inches='tight', dpi=300)
    plt.show()
    plt.close()

# Plot and display the confusion matrix
plot_confusion_matrix(y_test, y_pred_voting_default, "Default Ensemble Confusion Matrix")
# Out:
# Default Hard Voting Classifier Results:
# Accuracy: 0.7049
# Precision: 0.7500
# Recall: 0.5357
# F1 Score: 0.6250
#               precision    recall  f1-score   support
#
#            0       0.68      0.85      0.76        33
#            1       0.75      0.54      0.63        28
#
#     accuracy                           0.70        61
#    macro avg       0.72      0.69      0.69        61
# weighted avg       0.71      0.70      0.70        61
# time: 3.31 s (started: 2024-08-06 20:48:40 +00:00)

# %%
def load_data(participant_id):
    audio_file = f'{BASE_DIR}/{participant_id}/{participant_id}_AUDIO.wav'
    transcript_file = f'{BASE_DIR}/{participant_id}/{participant_id}_TRANSCRIPT.csv'
    y, sr = librosa.load(audio_file, sr=16000)
    transcript = pd.read_csv(transcript_file, sep='\t', header=None,
                             names=['start_time', 'stop_time', 'speaker', 'value'])
    if transcript.iloc[0]['start_time'] == 'start_time':
        transcript = transcript.iloc[1:]
    transcript['start_time'] = transcript['start_time'].astype(float)
    transcript['stop_time'] = transcript['stop_time'].astype(float)
    return y, sr, transcript

def segment_audio(y, sr, transcript):
    participant_segments = transcript[transcript['speaker'] != 'Ellie'].dropna(subset=['start_time', 'stop_time'])
    return np.concatenate([
        y[int(segment['start_time'] * sr):int(segment['stop_time'] * sr)]
        for _, segment in participant_segments.iterrows()
    ])

def time_stretch(audio, rate):
    return librosa.effects.time_stretch(audio, rate=rate)

def pitch_shift(audio, sr, n_steps):
    return librosa.effects.pitch_shift(audio, sr=sr, n_steps=n_steps)

def plot_waveforms(raw_audio, segmented_audio, time_stretched_audio, pitch_shifted_audio, sr):
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 5))
    
    ax1.plot(np.arange(len(raw_audio)) / sr, raw_audio, color='blue', linewidth=0.5)
    ax1.set_title('Raw Audio Sample')
    ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Amplitude')
    ax1.set_ylim(-1, 1)
    
    ax2.plot(np.arange(len(segmented_audio)) / sr, segmented_audio, color='blue', linewidth=0.5)
    ax2.set_title('Segmented Audio Sample')
    ax2.set_xlabel('Time (s)')
    ax2.set_ylabel('Amplitude')
    ax2.set_ylim(-1, 1)
    
    ax3.plot(np.arange(len(time_stretched_audio)) / sr, time_stretched_audio, color='blue', linewidth=0.5)
    ax3.set_title('Time Stretched Audio Sample')
    ax3.set_xlabel('Time (s)')
    ax3.set_ylabel('Amplitude')
    ax3.set_ylim(-1, 1)
    
    ax4.plot(np.arange(len(pitch_shifted_audio)) / sr, pitch_shifted_audio, color='blue', linewidth=0.5)
    ax4.set_title('Pitch Shifted Audio Sample')
    ax4.set_xlabel('Time (s)')
    ax4.set_ylabel('Amplitude')
    ax4.set_ylim(-1, 1)
    plt.savefig('raw_segmented_augmented_audio.png', dpi=300, bbox_inches='tight')
    plt.tight_layout()
    plt.show()

# Load the data file
data = pd.read_csv('/kaggle/input/depression-audio-dataset/depression-speech-all-kaggle/depression-speech-all-kaggle/train_split_temp-10.csv')

# Find a depressed participant
depression_column = 'PHQ8_Binary' if 'PHQ8_Binary' in data.columns else 'PHQ_Binary'
depressed_participant = data[data[depression_column] == 1].iloc[0]
participant_id = int(depressed_participant['Participant_ID'])

# Process the audio
y, sr, transcript = load_data(participant_id)
segmented_audio = segment_audio(y, sr, transcript)

# Apply time stretch and pitch shift separately
time_stretched_audio = time_stretch(segmented_audio, rate=np.random.uniform(0.8, 1.2))
pitch_shifted_audio = pitch_shift(segmented_audio, sr, n_steps=np.random.uniform(-2, 2))

# Plot the waveforms
plot_waveforms(y, segmented_audio, time_stretched_audio, pitch_shifted_audio, sr)
# Out:
# time: 26.8 s (started: 2024-08-06 21:29:23 +00:00)

# %%
# Base models with adjusted parameters
decision_tree = DecisionTreeClassifier(min_samples_leaf=4, min_samples_split=12, random_state=42)
random_forest = RandomForestClassifier(min_samples_split=12, n_estimators=200, random_state=42, class_weight='balanced')
gradient_boosting = GradientBoostingClassifier(learning_rate=0.01, max_depth=6, min_samples_leaf=2,
                                               min_samples_split=10, random_state=42, subsample=0.9)
knn = KNeighborsClassifier(n_neighbors=5)

# Fit the base models
decision_tree.fit(X_train_balanced_scaled, y_train_balanced)
random_forest.fit(X_train_balanced_scaled, y_train_balanced)
gradient_boosting.fit(X_train_balanced_scaled, y_train_balanced)
knn.fit(X_train_balanced_scaled, y_train_balanced)

# Define the hard voting classifier
voting_clf = VotingClassifier(
    estimators=[
        ('decision_tree', decision_tree),
        ('random_forest', random_forest),
        ('gradient_boosting', gradient_boosting),
        ('knn', knn)
    ],
    voting='hard'
)

# Fit the Voting Classifier
voting_clf.fit(X_train_balanced_scaled, y_train_balanced)

# Predict and evaluate
y_pred_voting = voting_clf.predict(X_test_scaled)
accuracy_voting = accuracy_score(y_test, y_pred_voting)
precision_voting = precision_score(y_test, y_pred_voting)
recall_voting = recall_score(y_test, y_pred_voting)
f1_voting = f1_score(y_test, y_pred_voting)

print("Step 1: Initial Hard Voting Classifier Results:")
print(f"Accuracy: {accuracy_voting:.4f}")
print(f"Precision: {precision_voting:.4f}")
print(f"Recall: {recall_voting:.4f}")
print(f"F1 Score: {f1_voting:.4f}")
print(classification_report(y_test, y_pred_voting))



# Adjust Random Forest to favor recall
random_forest_adjusted = RandomForestClassifier(min_samples_split=10, n_estimators=300, random_state=42, 
                                                class_weight='balanced_subsample', max_features='sqrt')
random_forest_adjusted.fit(X_train_balanced_scaled, y_train_balanced)

voting_clf_adjusted = VotingClassifier(
    estimators=[
        ('decision_tree', decision_tree),
        ('random_forest', random_forest_adjusted),
        ('gradient_boosting', gradient_boosting),
        ('knn', knn)
    ],
    voting='hard'
)

voting_clf_adjusted.fit(X_train_balanced_scaled, y_train_balanced)
y_pred_voting_adjusted = voting_clf_adjusted.predict(X_test_scaled)

accuracy_voting_adjusted = accuracy_score(y_test, y_pred_voting_adjusted)
precision_voting_adjusted = precision_score(y_test, y_pred_voting_adjusted)
recall_voting_adjusted = recall_score(y_test, y_pred_voting_adjusted)
f1_voting_adjusted = f1_score(y_test, y_pred_voting_adjusted)

print("\nStep 2: Adjusted Random Forest Results:")
print(f"Accuracy: {accuracy_voting_adjusted:.4f}")
print(f"Precision: {precision_voting_adjusted:.4f}")
print(f"Recall: {recall_voting_adjusted:.4f}")
print(f"F1 Score: {f1_voting_adjusted:.4f}")
print(classification_report(y_test, y_pred_voting_adjusted))

# Adjust Gradient Boosting to favor recall
gradient_boosting_adjusted = GradientBoostingClassifier(learning_rate=0.05, max_depth=5, min_samples_leaf=1,
                                                        min_samples_split=8, n_estimators=250, subsample=0.8, random_state=42)
gradient_boosting_adjusted.fit(X_train_balanced_scaled, y_train_balanced)

voting_clf_final = VotingClassifier(
    estimators=[
        ('decision_tree', decision_tree),
        ('random_forest', random_forest_adjusted),
        ('gradient_boosting', gradient_boosting_adjusted),
        ('knn', knn)
    ],
    voting='hard',
    weights=[1, 3, 2, 1]  # Give more weight to Random Forest and Gradient Boosting
)

voting_clf_final.fit(X_train_balanced_scaled, y_train_balanced)
y_pred_voting_final = voting_clf_final.predict(X_test_scaled)

accuracy_voting_final = accuracy_score(y_test, y_pred_voting_final)
precision_voting_final = precision_score(y_test, y_pred_voting_final)
recall_voting_final = recall_score(y_test, y_pred_voting_final)
f1_voting_final = f1_score(y_test, y_pred_voting_final)

print("\nStep 3: Final Adjusted Hard Voting Classifier Results:")
print(f"Accuracy: {accuracy_voting_final:.4f}")
print(f"Precision: {precision_voting_final:.4f}")
print(f"Recall: {recall_voting_final:.4f}")
print(f"F1 Score: {f1_voting_final:.4f}")
print(classification_report(y_test, y_pred_voting_final))


# Function to evaluate and plot individual classifier performance
def evaluate_classifier(classifier, X_train, y_train, X_test, y_test, name):
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    print(f"\n{name} Results:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(classification_report(y_test, y_pred))


# Evaluate individual classifiers
evaluate_classifier(decision_tree, X_train_balanced_scaled, y_train_balanced, X_test_scaled, y_test, "Decision Tree")
evaluate_classifier(random_forest_adjusted, X_train_balanced_scaled, y_train_balanced, X_test_scaled, y_test, "Random Forest")
evaluate_classifier(gradient_boosting_adjusted, X_train_balanced_scaled, y_train_balanced, X_test_scaled, y_test, "Gradient Boosting")
evaluate_classifier(knn, X_train_balanced_scaled, y_train_balanced, X_test_scaled, y_test, "KNN")

# Evaluate final ensemble
voting_clf_final.fit(X_train_balanced_scaled, y_train_balanced)
y_pred_final = voting_clf_final.predict(X_test_scaled)
accuracy_final = accuracy_score(y_test, y_pred_final)
precision_final = precision_score(y_test, y_pred_final)
recall_final = recall_score(y_test, y_pred_final)
f1_final = f1_score(y_test, y_pred_final)

print("\nFinal Ensemble Results:")
print(f"Accuracy: {accuracy_final:.4f}")
print(f"Precision: {precision_final:.4f}")
print(f"Recall: {recall_final:.4f}")
print(f"F1 Score: {f1_final:.4f}")
print(classification_report(y_test, y_pred_final))
# Out:
# Step 1: Initial Hard Voting Classifier Results:
# Accuracy: 0.8033
# Precision: 0.9000
# Recall: 0.6429
# F1 Score: 0.7500
#               precision    recall  f1-score   support
#
#            0       0.76      0.94      0.84        33
#            1       0.90      0.64      0.75        28
#
#     accuracy                           0.80        61
#    macro avg       0.83      0.79      0.79        61
# weighted avg       0.82      0.80      0.80        61
#
#
# Step 2: Adjusted Random Forest Results:
# Accuracy: 0.8033
# Precision: 0.9000
# Recall: 0.6429
# F1 Score: 0.7500
#               precision    recall  f1-score   support
#
#            0       0.76      0.94      0.84        33
#            1       0.90      0.64      0.75        28
#
#     accuracy                           0.80        61
#    macro avg       0.83      0.79      0.79        61
# weighted avg       0.82      0.80      0.80        61
#
#
# Step 3: Final Adjusted Hard Voting Classifier Results:
# Accuracy: 0.7869
# Precision: 0.7778
# Recall: 0.7500
# F1 Score: 0.7636
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        33
#            1       0.78      0.75      0.76        28
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.78      0.78        61
# weighted avg       0.79      0.79      0.79        61
#
#
# Decision Tree Results:
# Accuracy: 0.7705
# Precision: 0.7692
# Recall: 0.7143
# F1 Score: 0.7407
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79        33
#            1       0.77      0.71      0.74        28
#
#     accuracy                           0.77        61
#    macro avg       0.77      0.77      0.77        61
# weighted avg       0.77      0.77      0.77        61
#
#
# Random Forest Results:
# Accuracy: 0.7377
# Precision: 0.6875
# Recall: 0.7857
# F1 Score: 0.7333
#               precision    recall  f1-score   support
#
#            0       0.79      0.70      0.74        33
#            1       0.69      0.79      0.73        28
#
#     accuracy                           0.74        61
#    macro avg       0.74      0.74      0.74        61
# weighted avg       0.74      0.74      0.74        61
#
#
# Gradient Boosting Results:
# Accuracy: 0.7705
# Precision: 0.7917
# Recall: 0.6786
# F1 Score: 0.7308
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80        33
#            1       0.79      0.68      0.73        28
#
#     accuracy                           0.77        61
#    macro avg       0.77      0.76      0.77        61
# weighted avg       0.77      0.77      0.77        61
#
#
# KNN Results:
# Accuracy: 0.6721
# Precision: 0.7000
# Recall: 0.5000
# F1 Score: 0.5833
#               precision    recall  f1-score   support
#
#            0       0.66      0.82      0.73        33
#            1       0.70      0.50      0.58        28
#
#     accuracy                           0.67        61
#    macro avg       0.68      0.66      0.66        61
# weighted avg       0.68      0.67      0.66        61
#
#
# Final Ensemble Results:
# Accuracy: 0.7869
# Precision: 0.7778
# Recall: 0.7500
# F1 Score: 0.7636
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        33
#            1       0.78      0.75      0.76        28
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.78      0.78        61
# weighted avg       0.79      0.79      0.79        61
#
# time: 16.6 s (started: 2024-08-06 22:24:12 +00:00)

# %%
def get_top_features(classifier, feature_names, n=10):
    if hasattr(classifier, 'feature_importances_'):
        importances = classifier.feature_importances_
    elif hasattr(classifier, 'coef_'):
        importances = np.abs(classifier.coef_[0])
    else:
        return None  # For KNN, which doesn't have feature importances
    
    top_indices = importances.argsort()[-n:][::-1]
    top_features = [(feature_names[i], importances[i]) for i in top_indices]
    return top_features

# Get top features for each classifier in the final voting classifier
top_features_dt = get_top_features(voting_clf_final.named_estimators_['decision_tree'], feature_names)
top_features_rf = get_top_features(voting_clf_final.named_estimators_['random_forest'], feature_names)
top_features_gb = get_top_features(voting_clf_final.named_estimators_['gradient_boosting'], feature_names)

# Print top features for each classifier
classifiers = [
    ("Decision Tree", top_features_dt),
    ("Random Forest", top_features_rf),
    ("Gradient Boosting", top_features_gb)
]

for name, top_features in classifiers:
    if top_features:
        print(f"\nTop 10 features for {name}:")
        for feature, importance in top_features:
            print(f"{feature}: {importance:.4f}")

# Find common features
common_features = set([f for f, _ in top_features_dt]) & \
                  set([f for f, _ in top_features_rf]) & \
                  set([f for f, _ in top_features_gb])

print("\nCommon features across all classifiers:")
for feature in common_features:
    print(feature)
# Out:
# Top 10 features for Decision Tree:
# shimmerLocaldB_sma3nz_stddevNorm: 0.3747
# spectralFlux_sma3_stddevNorm: 0.0870
# jitterLocal_sma3nz_amean: 0.0698
# F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope: 0.0682
# F3frequency_sma3nz_stddevNorm: 0.0651
# alphaRatioV_sma3nz_stddevNorm: 0.0609
# logRelF0-H1-H2_sma3nz_stddevNorm: 0.0565
# F1bandwidth_sma3nz_stddevNorm: 0.0493
# F0semitoneFrom27.5Hz_sma3nz_stddevNorm: 0.0460
# alphaRatioUV_sma3nz_amean: 0.0389
#
# Top 10 features for Random Forest:
# shimmerLocaldB_sma3nz_stddevNorm: 0.0710
# loudness_sma3_meanRisingSlope: 0.0378
# loudness_sma3_stddevRisingSlope: 0.0358
# loudnessPeaksPerSec: 0.0309
# F2frequency_sma3nz_stddevNorm: 0.0270
# loudness_sma3_stddevFallingSlope: 0.0258
# slopeV0-500_sma3nz_amean: 0.0256
# VoicedSegmentsPerSec: 0.0206
# loudness_sma3_meanFallingSlope: 0.0178
# spectralFlux_sma3_stddevNorm: 0.0163
#
# Top 10 features for Gradient Boosting:
# shimmerLocaldB_sma3nz_stddevNorm: 0.2008
# loudness_sma3_meanRisingSlope: 0.0452
# F2frequency_sma3nz_stddevNorm: 0.0438
# slopeV0-500_sma3nz_amean: 0.0373
# spectralFlux_sma3_stddevNorm: 0.0290
# F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope: 0.0227
# slopeUV500-1500_sma3nz_amean: 0.0219
# logRelF0-H1-A3_sma3nz_stddevNorm: 0.0204
# F3bandwidth_sma3nz_amean: 0.0203
# F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope: 0.0192
#
# Common features across all classifiers:
# spectralFlux_sma3_stddevNorm
# shimmerLocaldB_sma3nz_stddevNorm
# time: 46.1 ms (started: 2024-08-06 22:24:40 +00:00)
